# %%
'''The below tutorial is the pull some tweets from twitter into a list->dataframe->csv file'''
# Out:
# 'The below tutorial is the pull some tweets from twitter into a list->dataframe->csv file'

# %%
# !pip install tweepy

# %%
import os
import tweepy as tw
import pandas as pd

# %%
consumer_key = "xxxxxxxxxxxx"
consumer_secret = "xxxxxxxxxxxxx"

# %%
access_token = "xxxxxxxxxxxxx"
access_token_secret = "xxxxxxxxxx"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_word = '#wildfires'
date_since = '2020-09-18'

# %%
tweets = tw.Cursor(api.search, q = search_word, lang = "en", since = date_since).items(5)

# %%
tweets

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# Anyone else sensing we're all being subjected to a "Shock and Awe" campaign?
#
# #ColoradoFires #ColoradoFire… https://t.co/bxHJPFOBYc
# RT @NCAR_ACOM: Night photo of #CalWoodFire at 7:00 PM MDT on Saturday, October 17,  2020, by @Elvastan. Taken from Gunbarrel between Boulde…
# Seeing the #wildfires and #drought in the #west and concerned about #ClimateChange but aren’t sure what you can do to help? Step 1, VOTE!
# Much appreciation for our partners at @DisabilityCA for the important work they do to educate, inform, and protect… https://t.co/KH3zHBSVKz
# All remaining evacuation warnings in #Humboldt for the August Complex have been lifted per @HumCoOES. #wildfires… https://t.co/jCawmurPbc

# %%
tweets = tw.Cursor(api.search,
                       q=search_word,
                       lang="en",
                       since=date_since).items(5)

[tweet.text for tweet in tweets]
# Out:
# ['Environmental and housing advocates, #BayArea electeds, civic leaders...we ALL should be in support of solving our… https://t.co/W9CuTYMyct',
#  'RT @ctmock: #ColoradoFires erupt amid deepening #drought, forcing evacuations in #BoulderCounty #wildfires #ClimateChange #ClimateEmergency…',
#  'RT @Nature_Colorado: Our hearts go out to all of those affected by the #wildfires in Colorado. Thank you to the brave firefighters and firs…',
#  'RT @ctmock: #ColoradoFires erupt amid deepening #drought, forcing evacuations in #BoulderCounty #wildfires #ClimateChange #ClimateEmergency…',
#  'RT @defis_eu: #ImageOfTheDay\n\nIn 2020, at least 1.1 million hectares have burned in #Bolivia 🇧🇴 due to severe #wildfires that are ravaging…']

# %%
tweets = tw.Cursor(api.search, 
                           q=search_word,
                           lang="en",
                           since=date_since).items(1000)

users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['pmagn', 'Canada'],
#  ['Andy_Tobin', 'Arizona,USA'],
#  ['ArizonaNewsnet', 'Arizona'],
#  ['earthanalyser', 'New Delhi, India'],
#  ['journtoolbox', 'Chicago, IL'],
#  ['MTColemanJr', 'Howard University'],
#  ['AlertingTucson', 'Tucson, AZ'],
#  ['GRFDAZ', 'Tucson, AZ'],
#  ['NightwatchN8', ''],
#  ['ctmock', 'Chicago, IL'],
#  ['____anpo', ''],
#  ['rwcoyote51', 'The Old Pueblo'],
#  ['clamjam22', 'Undisclosed location'],
#  ['NightwatchN8', ''],
#  ['cryptoscool', '🏔 🌊 '],
#  ['jonnygd', 'Boulder, CO'],
#  ['vance_taylor', 'Sacramento, CA'],
#  ['ncj_of_humboldt', 'Humboldt County, Calif.'],
#  ['JohnJRust', ''],
#  ['ucfoodobserver', 'University of California'],
#  ['SeanPaige', 'Colorado'],
#  ['vanja38925037', ''],
#  ['Renew_NV', 'Nevada, USA'],
#  ['MSLF', 'Denver, CO'],
#  ['FOXCATA7', 'Michigan, USA'],
#  ['3dogbenjamin', 'Fresno, CA'],
#  ['AngelaLipscom19', 'York, England'],
#  ['DawnRoseTurner', 'Comox Valley, BC'],
#  ['rick_hoyer', 'New York (600 miles from NYC)'],
# ...

# %%
tweets = tw.Cursor(api.search, 
                           q=search_word,
                           lang="en",
                           since=date_since).items(1000)

users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
from pandas import DataFrame
df=DataFrame(users_locs,columns=['username','location'])

# %%
df['location'].value_counts()[:20]
# Out:
#                               220
# New Orleans, Louisiana         50
# RT's Are FYI Purposes Only     30
# United States                  18
# Denver, CO                     18
# Kampala, Uganda                16
# Colorado, USA                  15
# California, USA                14
# Italy                          13
# USA                            12
# Washington, DC                  9
# Boulder, CO                     9
# Colorado                        8
# Boulder, Colorado               7
# Belgique                        7
# Washington, D.C.                6
# India                           6
# New Mexico USA                  6
# Portland, Oregon                6
# Los Angeles, CA                 5
# Name: location, dtype: int64

# %%
df['location'].value_counts()[:20].plot(kind = 'bar')

# %%
df.to_csv("C:/Users/rprad/Downloads/scrape.csv")
